# %% [markdown]
# <a href="https://colab.research.google.com/github/mrtkp9993/FinanceExamplePy/blob/main/00_get_stock_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf

# %%
bist30h = [
    "TUPRS.IS",
    "VAKBN.IS",
    "KRDMD.IS",
    "DOHOL.IS",
    "AKBNK.IS",
    "TKFEN.IS",
    "FROTO.IS",
    "GARAN.IS",
    "KOZAA.IS",
    "HALKB.IS",
    "TCELL.IS",
    "KOZAL.IS",
    "VESTL.IS",
    "YKBNK.IS",
    "TTKOM.IS",
    "BIMAS.IS",
    "PETKM.IS",
    "SISE.IS",
    "ARCLK.IS",
    "EREGL.IS",
    "SASA.IS",
    "SAHOL.IS",
    "EKGYO.IS",
    "THYAO.IS",
    "PGSUS.IS",
    "ISCTR.IS",
    "KCHOL.IS",
    "ASELS.IS",
    "TAVHL.IS",
    "GUBRF.IS",
]

# %%
data = yf.download(tickers=" ".join(bist30h), period="max", start="2005-01-01")

data.clip(lower=0, inplace=True)
data.fillna(0, inplace=True)
# Out:
# [*********************100%***********************]  30 of 30 completed

# %%
data["Adj Close"].plot()
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.tight_layout(pad=7)
plt.show()
# Out:
# C:\Users\murat\AppData\Local\Temp/ipykernel_19712/18623610.py:3: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout(pad=7)

# %%
data.to_csv("00_data.csv")
